# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhamJadhav03/DeepLearning/blob/main/Matrics_Rev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
Revenue_mil= np.array([[200, 68, 110, 80], [220, 79, 140, 85], [250, 105, 180, 90]])

# %%
Revenue_mil
# Out:
# array([[200,  68, 110,  80],
#        [220,  79, 140,  85],
#        [250, 105, 180,  90]])

# %%
Revenue_inr =  Revenue_mil * 75

# %%
Revenue_inr
# Out:
# array([[15000,  5100,  8250,  6000],
#        [16500,  5925, 10500,  6375],
#        [18750,  7875, 13500,  6750]])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Flowers_monthly_unit_sold = np.array([[50, 10, 40], [10, 13, 5], [40, 70, 52]])

# %%
price_per_unit = np.array([[20, 30, 15]])

# %%
np.dot(price_per_unit, Flowers_monthly_unit_sold)
# Out:
# array([[1900, 1640, 1730]])
